# %% [markdown]
# # Inception v3 attacks

# %% [markdown]
# ## Librerías

# %%
import numpy as np
import random
import matplotlib.pyplot as plt
import pandas as pd
from tqdm import tqdm

from PIL import Image

import torch
import torch.nn as nn
from torch.utils.data import DataLoader, TensorDataset, Dataset
from torchinfo import summary

from torchvision import models
import torchvision.transforms as transforms

import torchattacks

from utils.datasets import MyDataset
from utils.evaluation import NormalizationLayer, get_topk_accuracy
from utils.evaluation import plot_adversarial, get_same_predictions, get_different_predictions

import warnings
warnings.filterwarnings('ignore')

# %%
# Reproducibility
random.seed(42)
np.random.seed(42)
torch.manual_seed(42)
torch.backends.cudnn.deterministic = True

# %%
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')
device
# Out:
# device(type='cuda', index=0)

# %% [markdown]
# ## Modelo
#
# De acuerdo a la documentación de PyTorch se tiene lo siguiente:
#
# - [Inception](https://pytorch.org/hub/pytorch_vision_inception_v3/): top-1-error de 22.55% and top-5-error de 6.44%. La salida tiene puntuaciones no normalizadas, para obtener probabilidades hay que ejecutar un softmax en la salida.

# %% [markdown]
# Por la forma en que funciona [Adversarial-Attacks-PyTorch](https://github.com/Harry24k/adversarial-attacks-pytorch) las imágenes de entrada que se le tienen que pasar deben estar en el rango [0,1], pero los modelos pre-entrenados de PyTorch esperan imágenes normalizadas, las cuáles no están en el [0,1]. La forma de resolver ésto es añadiendo una capa de normalización al inicio. Ver [Demo - White Box Attack (Imagenet)](https://nbviewer.jupyter.org/github/Harry24k/adversarial-attacks-pytorch/blob/master/demos/White%20Box%20Attack%20%28ImageNet%29.ipynb) para un ejemplo con los modelos entrenados en ImageNet.

# %%
inception_v3 = nn.Sequential(
    NormalizationLayer(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
    models.inception_v3(pretrained=True))

# %%
summary(inception_v3)
# Out:
# =================================================================
# Layer (type:depth-idx)                   Param #
# =================================================================
# Sequential                               --
# ├─NormalizationLayer: 1-1                --
# ├─Inception3: 1-2                        --
# │    └─BasicConv2d: 2-1                  --
# │    │    └─Conv2d: 3-1                  864
# │    │    └─BatchNorm2d: 3-2             64
# │    └─BasicConv2d: 2-2                  --
# │    │    └─Conv2d: 3-3                  9,216
# │    │    └─BatchNorm2d: 3-4             64
# │    └─BasicConv2d: 2-3                  --
# │    │    └─Conv2d: 3-5                  18,432
# │    │    └─BatchNorm2d: 3-6             128
# │    └─BasicConv2d: 2-4                  --
# │    │    └─Conv2d: 3-7                  5,120
# │    │    └─BatchNorm2d: 3-8             160
# │    └─BasicConv2d: 2-5                  --
# │    │    └─Conv2d: 3-9                  138,240
# │    │    └─BatchNorm2d: 3-10            384
# │    └─InceptionA: 2-6                   --
# │    │    └─BasicConv2d: 3-11            12,416
# │    │    └─BasicConv2d: 3-12            9,312
# │    │    └─BasicConv2d: 3-13            76,928
# │    │    └─BasicConv2d: 3-14            12,416
# │    │    └─BasicConv2d: 3-15            55,488
# │    │    └─BasicConv2d: 3-16            83,136
# │    │    └─BasicConv2d: 3-17            6,208
# │    └─InceptionA: 2-7                   --
# │    │    └─BasicConv2d: 3-18            16,512
# │    │    └─BasicConv2d: 3-19            12,384
# │    │    └─BasicConv2d: 3-20            76,928
# │    │    └─BasicConv2d: 3-21            16,512
# │    │    └─BasicConv2d: 3-22            55,488
# │    │    └─BasicConv2d: 3-23            83,136
# │    │    └─BasicConv2d: 3-24            16,512
# │    └─InceptionA: 2-8                   --
# │    │    └─BasicConv2d: 3-25            18,560
# │    │    └─BasicConv2d: 3-26            13,920
# │    │    └─BasicConv2d: 3-27            76,928
# │    │    └─BasicConv2d: 3-28            18,560
# │    │    └─BasicConv2d: 3-29            55,488
# │    │    └─BasicConv2d: 3-30            83,136
# │    │    └─BasicConv2d: 3-31            18,560
# │    └─InceptionB: 2-9                   --
# │    │    └─BasicConv2d: 3-32            996,096
# │    │    └─BasicConv2d: 3-33            18,560
# │    │    └─BasicConv2d: 3-34            55,488
# │    │    └─BasicConv2d: 3-35            83,136
# │    └─InceptionC: 2-10                  --
# │    │    └─BasicConv2d: 3-36            147,840
# │    │    └─BasicConv2d: 3-37            98,560
# │    │    └─BasicConv2d: 3-38            114,944
# │    │    └─BasicConv2d: 3-39            172,416
# │    │    └─BasicConv2d: 3-40            98,560
# │    │    └─BasicConv2d: 3-41            114,944
# │    │    └─BasicConv2d: 3-42            114,944
# │    │    └─BasicConv2d: 3-43            114,944
# │    │    └─BasicConv2d: 3-44            172,416
# │    │    └─BasicConv2d: 3-45            147,840
# │    └─InceptionC: 2-11                  --
# │    │    └─BasicConv2d: 3-46            147,840
# │    │    └─BasicConv2d: 3-47            123,200
# │    │    └─BasicConv2d: 3-48            179,520
# │    │    └─BasicConv2d: 3-49            215,424
# │    │    └─BasicConv2d: 3-50            123,200
# │    │    └─BasicConv2d: 3-51            179,520
# │    │    └─BasicConv2d: 3-52            179,520
# │    │    └─BasicConv2d: 3-53            179,520
# │    │    └─BasicConv2d: 3-54            215,424
# │    │    └─BasicConv2d: 3-55            147,840
# │    └─InceptionC: 2-12                  --
# │    │    └─BasicConv2d: 3-56            147,840
# │    │    └─BasicConv2d: 3-57            123,200
# │    │    └─BasicConv2d: 3-58            179,520
# │    │    └─BasicConv2d: 3-59            215,424
# │    │    └─BasicConv2d: 3-60            123,200
# │    │    └─BasicConv2d: 3-61            179,520
# │    │    └─BasicConv2d: 3-62            179,520
# │    │    └─BasicConv2d: 3-63            179,520
# │    │    └─BasicConv2d: 3-64            215,424
# │    │    └─BasicConv2d: 3-65            147,840
# │    └─InceptionC: 2-13                  --
# │    │    └─BasicConv2d: 3-66            147,840
# │    │    └─BasicConv2d: 3-67            147,840
# │    │    └─BasicConv2d: 3-68            258,432
# │    │    └─BasicConv2d: 3-69            258,432
# │    │    └─BasicConv2d: 3-70            147,840
# │    │    └─BasicConv2d: 3-71            258,432
# │    │    └─BasicConv2d: 3-72            258,432
# │    │    └─BasicConv2d: 3-73            258,432
# │    │    └─BasicConv2d: 3-74            258,432
# │    │    └─BasicConv2d: 3-75            147,840
# │    └─InceptionAux: 2-14                --
# │    │    └─BasicConv2d: 3-76            98,560
# │    │    └─BasicConv2d: 3-77            2,459,136
# │    │    └─Linear: 3-78                 769,000
# │    └─InceptionD: 2-15                  --
# │    │    └─BasicConv2d: 3-79            147,840
# │    │    └─BasicConv2d: 3-80            553,600
# │    │    └─BasicConv2d: 3-81            147,840
# │    │    └─BasicConv2d: 3-82            258,432
# │    │    └─BasicConv2d: 3-83            258,432
# │    │    └─BasicConv2d: 3-84            332,160
# │    └─InceptionE: 2-16                  --
# │    │    └─BasicConv2d: 3-85            410,240
# │    │    └─BasicConv2d: 3-86            492,288
# │    │    └─BasicConv2d: 3-87            443,136
# │    │    └─BasicConv2d: 3-88            443,136
# │    │    └─BasicConv2d: 3-89            574,336
# │    │    └─BasicConv2d: 3-90            1,549,056
# │    │    └─BasicConv2d: 3-91            443,136
# │    │    └─BasicConv2d: 3-92            443,136
# │    │    └─BasicConv2d: 3-93            246,144
# │    └─InceptionE: 2-17                  --
# │    │    └─BasicConv2d: 3-94            656,000
# │    │    └─BasicConv2d: 3-95            787,200
# │    │    └─BasicConv2d: 3-96            443,136
# │    │    └─BasicConv2d: 3-97            443,136
# │    │    └─BasicConv2d: 3-98            918,400
# │    │    └─BasicConv2d: 3-99            1,549,056
# │    │    └─BasicConv2d: 3-100           443,136
# │    │    └─BasicConv2d: 3-101           443,136
# │    │    └─BasicConv2d: 3-102           393,600
# │    └─Linear: 2-18                      2,049,000
# =================================================================
# Total params: 27,161,264
# Trainable params: 27,161,264
# Non-trainable params: 0
# =================================================================

# %%
# Lo movemos a la GPU, en caso de que haya
inception_v3 = inception_v3.to(device)

# %% [markdown]
# ## Dataset & dataloader

# %%
my_dataset = MyDataset(root_dir='../../data/images/', 
                       images_csv='../../data/images.csv',
                       categories_csv='../../data/categories.csv',
                       normalize=False)

# %%
dataloader  = torch.utils.data.DataLoader(my_dataset, batch_size=32, shuffle=False, num_workers=4)

# %% [markdown]
# ## Ataques
#
# Los siguientes son todos los ataques que están disponibles en [Adversarial-Attacks-PyTorch](https://github.com/Harry24k/adversarial-attacks-pytorch):
#
# ```python
# attacks = [torchattacks.FGSM(model, eps=8/255),
#            torchattacks.BIM(model, eps=8/255, alpha=2/255, steps=7),
#            torchattacks.CW(model, c=1, kappa=0, steps=1000, lr=0.01),
#            torchattacks.RFGSM(model, eps=8/255, alpha=4/255, steps=1),
#            torchattacks.PGD(model, eps=8/255, alpha=2/255, steps=7),
#            torchattacks.FFGSM(model, eps=8/255, alpha=12/255),
#            torchattacks.TPGD(model, eps=8/255, alpha=2/255, steps=7),
#            torchattacks.MIFGSM(model, eps=8/255, decay=1.0, steps=5),
#            torchattacks.APGD(model, eps=8/255, steps=10),
#            torchattacks.FAB(model, eps=8/255),
#            torchattacks.Square(model, eps=8/255),
#            torchattacks.PGDDLR(model, eps=8/255, alpha=2/255, steps=7),
#            torchattacks.DeepFool(model, steps=50, overshoot=0.02),
#            torchattacks.OnePixel(model, pixels=1, steps=75, popsize=400),
#            torchattacks.SparseFool(model, steps=20, lam=3, overshoot=0.02)]
# ```
#
# No probaré todos ya que son bastantes, por lo que tomaré:
#
# - `torchattacks.FGSM`: fue el primer algortimo para generar ataques, ver [Explaining and harnessing adversarial examples (Goodfellow et al., 2014)](https://arxiv.org/abs/1412.6572).
# - `torchattacks.PGD`: uno de los algoritmos que usa el gradiente, he visto que lo usan en varios lugares, ver [Towards Deep Learning Models Resistant to Adversarial Attacks (Mardry et al., 2017)](https://arxiv.org/abs/1706.06083).
# - `torchattacks.MIFGSM`: también usa el gradiente pero le añade momento, ver [Boosting Adversarial Attacks with Momentum (Dong et al., 2017)](https://arxiv.org/abs/1710.06081). Este algoritmo fue uno de los ganadores de la competencia [NIPS 2017: Non-targeted Adversarial Attack
# ](https://www.kaggle.com/c/nips-2017-non-targeted-adversarial-attack/overview).
# - `torchattacks.OnePixel`: ataque a un sólo pixel, quiero jugar con este algoritmo sólo para ver qué tan robustas son las redes que usaré y está divertido, ver [One pixel attack for fooling deep neural networks (Su et al., 2019)](https://arxiv.org/abs/1710.08864).
#
# Usaré algunos de los parámetros que recomienda para un ataque de caja blanca con ImageNet, ver [White Box Attack (Imagenet)](https://nbviewer.jupyter.org/github/Harry24k/adversarial-attacks-pytorch/blob/master/demos/White%20Box%20Attack%20%28ImageNet%29.ipynb).

# %% [markdown]
# ### FGSM

# %%
# %%time

attack = torchattacks.FGSM(inception_v3, eps=1/255)
attack.set_return_type('float') 
attack.save(dataloader, save_path='models/inception_v3/FGSM.pt', verbose=True)
# Out:
# - Save Progress: 100.00 % / Accuracy: 10.80 % / L2: 1.49501
# - Save Complete!
# CPU times: user 8.63 s, sys: 1.22 s, total: 9.85 s
# Wall time: 7.95 s

# %% [markdown]
# ### PGD

# %%
# %%time

attack = torchattacks.PGD(inception_v3, eps=1/255, alpha=1/255, steps=3)
attack.set_return_type('float') 
attack.save(dataloader, save_path='models/inception_v3/PGD.pt', verbose=True)
# Out:
# - Save Progress: 100.00 % / Accuracy: 3.90 % / L2: 1.34724
# - Save Complete!
# CPU times: user 15.3 s, sys: 6.05 s, total: 21.3 s
# Wall time: 18.7 s

# %% [markdown]
# ### MIFGSM

# %%
# %%time

attack = torchattacks.MIFGSM(inception_v3, eps=1/255, decay=1.0, steps=3)
attack.set_return_type('float') 
attack.save(dataloader, save_path='models/inception_v3/MIFGSM.pt', verbose=True)
# Out:
# - Save Progress: 100.00 % / Accuracy: 5.10 % / L2: 1.27701
# - Save Complete!
# CPU times: user 15.4 s, sys: 6.2 s, total: 21.6 s
# Wall time: 19.1 s

# %% [markdown]
# ### OnePixel

# %%
# %%time

attack = torchattacks.OnePixel(inception_v3, pixels=1, steps=5, popsize=20)
attack.set_return_type('float') 
attack.save(dataloader, save_path='models/inception_v3/OnePixel.pt', verbose=True)
# Out:
# - Save Progress: 100.00 % / Accuracy: 70.10 % / L2: 0.81212
# - Save Complete!
# CPU times: user 3min 24s, sys: 1.64 s, total: 3min 26s
# Wall time: 3min 23s

# %% [markdown]
# ## Evaluación

# %% [markdown]
# ### Limpio

# %% [markdown]
# En [torchvision.models](https://pytorch.org/vision/stable/models.html) vemos que el accuracy es parecido a lo que sale con este dataset.

# %%
dataloader_eval  = torch.utils.data.DataLoader(my_dataset, batch_size=None, shuffle=False, num_workers=4)

y_true, y_pred, accuracy_1, accuracy_5 = get_topk_accuracy(inception_v3, dataloader_eval)
print(f'Accuracy@1: {accuracy_1}')
print(f'Accuracy@5: {accuracy_5}')
# Out:
# 100%|██████████| 1000/1000 [00:12<00:00, 81.13it/s]
# Accuracy@1: 76.5
# Accuracy@5: 93.10000000000001

# %% [markdown]
# ### FGSM

# %%
# The adversarial images are in [0,1], so NormalizationLayer prepares them for the pre-trained model 
adv_images, adv_labels = torch.load('models/inception_v3/FGSM.pt')
adv_dataset = TensorDataset(adv_images, adv_labels)
adv_loader = DataLoader(adv_dataset, batch_size=None, shuffle=False, num_workers=4)

y_true_adv, y_pred_adv, accuracy_1, accuracy_5 = get_topk_accuracy(inception_v3, adv_loader)
print(f'Accuracy@1: {accuracy_1}')
print(f'Accuracy@5: {accuracy_5}')
# Out:
# 100%|██████████| 1000/1000 [00:12<00:00, 79.44it/s]
# Accuracy@1: 10.8
# Accuracy@5: 39.300000000000004

# %%
# {650: 'bee', 231: 'zebra', 834: 'white shark', 891: 'hummingbird', 535: 'panda'}
i = 891
plot_adversarial(my_dataset, adv_dataset, y_pred, y_pred_adv, i)

# %% [markdown]
# ### PGD

# %%
# The adversarial images are in [0,1], so NormalizationLayer prepares them for the pre-trained model 
adv_images, adv_labels = torch.load('models/inception_v3/PGD.pt')
adv_dataset = TensorDataset(adv_images, adv_labels)
adv_loader = DataLoader(adv_dataset, batch_size=None, shuffle=False, num_workers=4)

y_true_adv, y_pred_adv, accuracy_1, accuracy_5 = get_topk_accuracy(inception_v3, adv_loader)
print(f'Accuracy@1: {accuracy_1}')
print(f'Accuracy@5: {accuracy_5}')
# Out:
# 100%|██████████| 1000/1000 [00:12<00:00, 79.30it/s]
# Accuracy@1: 3.9
# Accuracy@5: 28.1

# %%
# {650: 'bee', 231: 'zebra', 834: 'white shark', 891: 'hummingbird', 535: 'panda'}
i = 891
plot_adversarial(my_dataset, adv_dataset, y_pred, y_pred_adv, i)

# %% [markdown]
# ### MIFGSM

# %%
# The adversarial images are in [0,1], so NormalizationLayer prepares them for the pre-trained model 
adv_images, adv_labels = torch.load('models/inception_v3/MIFGSM.pt')
adv_dataset = TensorDataset(adv_images, adv_labels)
adv_loader = DataLoader(adv_dataset, batch_size=None, shuffle=False, num_workers=4)

y_true_adv, y_pred_adv, accuracy_1, accuracy_5 = get_topk_accuracy(inception_v3, adv_loader)
print(f'Accuracy@1: {accuracy_1}')
print(f'Accuracy@5: {accuracy_5}')
# Out:
# 100%|██████████| 1000/1000 [00:12<00:00, 78.67it/s]
# Accuracy@1: 5.1
# Accuracy@5: 27.6

# %%
# {650: 'bee', 231: 'zebra', 834: 'white shark', 891: 'hummingbird', 535: 'panda'}
i = 891
plot_adversarial(my_dataset, adv_dataset, y_pred, y_pred_adv, i)

# %% [markdown]
# ### OnePixel

# %%
# The adversarial images are in [0,1], so NormalizationLayer prepares them for the pre-trained model 
adv_images, adv_labels = torch.load('models/inception_v3/OnePixel.pt')
adv_dataset = TensorDataset(adv_images, adv_labels)
adv_loader = DataLoader(adv_dataset, batch_size=None, shuffle=False, num_workers=4)

y_true_adv, y_pred_adv, accuracy_1, accuracy_5 = get_topk_accuracy(inception_v3, adv_loader)
print(f'Accuracy@1: {accuracy_1}')
print(f'Accuracy@5: {accuracy_5}')
# Out:
# 100%|██████████| 1000/1000 [00:12<00:00, 79.05it/s]
# Accuracy@1: 70.1
# Accuracy@5: 91.8

# %%
different_predictions = get_different_predictions(y_pred, y_pred_adv)
i = different_predictions[0]

print(f'Truth: {my_dataset.idx_to_class[y_true[i]]}')
plot_adversarial(my_dataset, adv_dataset, y_pred, y_pred_adv, i)
# Out:
# Truth: drum, membranophone, tympan
